# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
labels=['python','c','c++','java','r']
sizes=np.array([250,130,200,210,100])
colors=['yellow','yellowgreen','pink','pink','blue','red']
exp=[0,0,0,0,1]

# %%
def calc(val):

# %%
x = np.arange(0,3*np.pi,0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.plot(x,y_sin,'r')
plt.plot(x,y_cos,'*')

# %%
df=pd.read_csv('iris.csv',names=('a','b','c','d','e'),sep=',')

# %%
x=np.array(df.a)
y=np.array(df.b)
plt.plot(x,y)

# %%
x=[10,14,17,19,21,25,27]
y=[3,5,7,9,11,13,19]
plt.scatter(x,y)

# %%
import nltk
