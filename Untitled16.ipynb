# %%
import seaborn as sn

# %%
import matplotlib.pyplot as plt
import pandas as pd
fig,ax = plt.subplots()
data = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")
ax.violinplot(data["tip"])
plt.xlabel('Tips')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
tips = sn.load_dataset("tips")
sn.violinplot(x=tips.tip,data=tips)
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips = sn.load_dataset("tips")
sn.swarmplot(x="tip", y="smoker", data=tips)

# %%
titanic = sn.load_dataset("titanic")
g = sn.factorplot("class","survived","sex",data=titanic,kind="bar",palette="muted",legend=True)

# %%
def sinplot(f=1):
    x=np.linspace(0, 8, 100)
    for i in range(1,7):
        plt.plot(x,np.sin(x+1*.5))
sn.set()
sn.set_style('dark')
sinplot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-5c3c80c89a6e> in <module>
#       5 sn.set()
#       6 sn.set_style('dark')
# ----> 7 sinplot()
#
# <ipython-input-30-5c3c80c89a6e> in sinplot(f)
#       1 def sinplot(f=1):
# ----> 2     x=np.linspace(0, 8, 100)
#       3     for i in range(1,7):
#       4         plt.plot(x,np.sin(x+1*.5))
#       5 sn.set()
#
# NameError: name 'np' is not defined

# %%
#data= np.random.normal(size)

# %%
si
sn.dispine()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-b1b79f75714e> in <module>
# ----> 1 sn.dispine()
#
# AttributeError: module 'seaborn' has no attribute 'dispine'

# %%
sn.violinplot

# %%
df=sn.load_dataset('iris')
sn.kdeplot(df['sepal_width'], shade=True, bw=.9,vertical=True,)
